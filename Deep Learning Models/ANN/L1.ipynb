# %%
import pandas as pd

# %%
df = pd.read_csv("Market_data_set.csv")
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  QTR_ID  \
# 0               30      95.70                2  2871.00  Shipped       1
# 1               34      81.35                5  2765.90  Shipped       2
# 2               41      94.74                2  3884.34  Shipped       3
# 3               45      83.26                6  3746.70  Shipped       3
# 4               49     100.00               14  5205.27  Shipped       4
#
#    MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  Product_SK PRODUCTCODE  Customer_SK  \
# 0         2     2003  Motorcycles    95           1    S10_1678            1
# 1         5     2003  Motorcycles    95           2    S10_1678            2
# 2         7     2003  Motorcycles    95           3    S10_1678            3
# 3         8     2003  Motorcycles    95           4    S10_1678            4
# 4        10     2003  Motorcycles    95           5    S10_1678            5
#
#   COUNTRY DEALSIZE
# 0     USA    Small
# 1  France    Small
# 2  France   Medium
# 3     USA   Medium
# 4     USA   Medium

# %%
df.isna().sum() # There are no missing values
# Out:
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# STATUS             0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# PRODUCTLINE        0
# MSRP               0
# Product_SK         0
# PRODUCTCODE        0
# Customer_SK        0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

df_encoded = pd.DataFrame()
columns_to_encode = ['STATUS', 'PRODUCTLINE', 'PRODUCTCODE', 'COUNTRY', 'DEALSIZE']
for column in columns_to_encode:
    df_encoded[column] = label_encoder.fit_transform(df[column])

df_encoded.head()
# Out:
#    STATUS  PRODUCTLINE  PRODUCTCODE  COUNTRY  DEALSIZE
# 0       5            1            0       18         2
# 1       5            1            0        6         2
# 2       5            1            0        6         1
# 3       5            1            0       18         1
# 4       5            1            0       18         1

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numeric_columns = df.select_dtypes(include=['number'])
df_encoded[numeric_columns.columns] = scaler.fit_transform(df[numeric_columns.columns])
df_encoded
# Out:
#       STATUS  PRODUCTLINE  PRODUCTCODE  COUNTRY  DEALSIZE  QUANTITYORDERED  \
# 0          5            1            0       18         2        -0.522891
# 1          5            1            0        6         2        -0.112201
# 2          5            1            0        6         1         0.606505
# 3          5            1            0       18         1         1.017195
# 4          5            1            0       18         1         1.427884
# ...      ...          ...          ...      ...       ...              ...
# 2818       5            3          108       14         2        -1.549615
# 2819       5            3          108        5         1        -0.625563
# 2820       4            3          108       14         1         0.811850
# 2821       5            3          108        6         2        -0.112201
# 2822       3            3          108       18         1         1.222540
#
#       PRICEEACH  ORDERLINENUMBER     SALES    QTR_ID  MONTH_ID   YEAR_ID  \
# 0      0.596978        -1.057059 -0.370825 -1.427039 -1.392909 -1.165170
# 1     -0.114450        -0.347015 -0.427897 -0.596243 -0.572337 -1.165170
# 2      0.549384        -1.057059  0.179443  0.234553 -0.025289 -1.165170
# 3     -0.019759        -0.110334  0.104701  0.234553  0.248235 -1.165170
# 4      0.810158         1.783116  0.896740  1.065350  0.795284 -1.165170
# ...         ...              ...       ...       ...       ...       ...
# 2818   0.810158         2.019797 -0.711084  1.065350  1.342332  0.264328
# 2819   0.810158        -1.293740  0.230579 -1.427039 -1.666433  1.693826
# 2820   0.810158        -0.583696  1.012024 -1.427039 -1.119385  1.693826
# 2821  -1.061864        -1.293740 -0.780722 -1.427039 -1.119385  1.693826
# 2822  -0.899252         0.599710 -0.257637 -0.596243 -0.572337  1.693826
#
#           MSRP  Product_SK  Customer_SK
# 0    -0.142246   -1.731437    -1.731437
# 1    -0.142246   -1.730210    -1.730210
# 2    -0.142246   -1.728983    -1.728983
# 3    -0.142246   -1.727756    -1.727756
# 4    -0.142246   -1.726529    -1.726529
# ...        ...         ...          ...
# 2818 -1.162634    1.726529     1.726529
# 2819 -1.162634    1.727756     1.727756
# 2820 -1.162634    1.728983     1.728983
# 2821 -1.162634    1.730210     1.730210
# 2822 -1.162634    1.731437     1.731437
#
# [2823 rows x 15 columns]

# %%
# from sklearn.model_selection import train_test_split
# train, test = train_test_split(df_encoded, test_size=0.2, random_state=42)

# %%
X = df_encoded.drop('DEALSIZE', axis=1).values
Y = df_encoded['DEALSIZE'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
y_test[0]
# Out:
# 2

# %%
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(16, input_shape=(14,), activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(3, activation = 'sigmoid')
])

# %%
# Compilation of model
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)

# %%
# fitting the model
history = model.fit(X_train, y_train,
          epochs=30, validation_data=(X_test, y_test), batch_size=32,callbacks=[es])
# Out:
# Epoch 1/30
# 71/71 [==============================] - 1s 3ms/step - loss: 1.2150 - accuracy: 0.5093 - val_loss: 0.8007 - val_accuracy: 0.7027
# Epoch 2/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6842 - accuracy: 0.7263 - val_loss: 0.5999 - val_accuracy: 0.8212
# Epoch 3/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.8326 - val_loss: 0.4320 - val_accuracy: 0.8584
# Epoch 4/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3710 - accuracy: 0.8760 - val_loss: 0.3761 - val_accuracy: 0.8496
# Epoch 5/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3074 - accuracy: 0.8787 - val_loss: 0.2796 - val_accuracy: 0.8991
# Epoch 6/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.8995 - val_loss: 0.2554 - val_accuracy: 0.8867
# Epoch 7/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.9119 - val_loss: 0.2825 - val_accuracy: 0.8779
# Epoch 8/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2077 - accuracy: 0.9194 - val_loss: 0.2021 - val_accuracy: 0.9115
# Epoch 9/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.9265 - val_loss: 0.1972 - val_accuracy: 0.9027
# Epoch 10/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1729 - accuracy: 0.9269 - val_loss: 0.2200 - val_accuracy: 0.8885
# Epoch 11/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1708 - accuracy: 0.9274 - val_loss: 0.1578 - val_accuracy: 0.9292
# Epoch 12/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1485 - accuracy: 0.9371 - val_loss: 0.1754 - val_accuracy: 0.9239
# Epoch 13/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.9477 - val_loss: 0.1515 - val_accuracy: 0.9292
# Epoch 14/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9376 - val_loss: 0.1469 - val_accuracy: 0.9363
# Epoch 15/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 0.9508 - val_loss: 0.1482 - val_accuracy: 0.9327
# Epoch 16/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1211 - accuracy: 0.9504 - val_loss: 0.1400 - val_accuracy: 0.9416
# Epoch 17/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.1124 - accuracy: 0.9539 - val_loss: 0.1278 - val_accuracy: 0.9416
# Epoch 18/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1077 - accuracy: 0.9557 - val_loss: 0.1408 - val_accuracy: 0.9363
# Epoch 19/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.1076 - accuracy: 0.9544 - val_loss: 0.1325 - val_accuracy: 0.9363
# Epoch 20/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.1094 - accuracy: 0.9544 - val_loss: 0.1164 - val_accuracy: 0.9522
# Epoch 21/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1005 - accuracy: 0.9588 - val_loss: 0.1290 - val_accuracy: 0.9381
# Epoch 22/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9650 - val_loss: 0.1195 - val_accuracy: 0.9487
# Epoch 23/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.0884 - accuracy: 0.9686 - val_loss: 0.1538 - val_accuracy: 0.9416
# Epoch 24/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.0983 - accuracy: 0.9601 - val_loss: 0.1094 - val_accuracy: 0.9593
# Epoch 25/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 0.9686 - val_loss: 0.1355 - val_accuracy: 0.9522
# Epoch 26/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.1036 - accuracy: 0.9531 - val_loss: 0.1610 - val_accuracy: 0.9398
# Epoch 27/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9570 - val_loss: 0.1246 - val_accuracy: 0.9487
# Epoch 28/30
# 71/71 [==============================] - 0s 1ms/step - loss: 0.0839 - accuracy: 0.9677 - val_loss: 0.1067 - val_accuracy: 0.9575
# Epoch 29/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9646 - val_loss: 0.1051 - val_accuracy: 0.9593
# Epoch 30/30
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9725 - val_loss: 0.1672 - val_accuracy: 0.9398

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy:.2f}')

loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Loss: {loss[0]:.2f}')
# Out:
# 18/18 [==============================] - 0s 1ms/step
# Accuracy: 0.94
# Loss: 0.17

# %%
from sklearn.metrics import classification_report

classification_report_str = classification_report(y_test, y_pred_classes)

# Print the classification report
print('Classification Report:\n', classification_report_str)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.93      0.95      0.94       272
#            2       0.99      0.92      0.95       252
#
#     accuracy                           0.94       565
#    macro avg       0.90      0.96      0.92       565
# weighted avg       0.95      0.94      0.94       565
